# %%
# %pip install gazpacho --upgrade

# %%
URL = "https://en.wikipedia.org/wiki/List_of_world_records_in_swimming"

import gazpacho

html = gazpacho.get(URL)

len(html)
# Out:
# 572518

# %%
html[:500]

# %%
html[-500:]

# %%
print(dir(html))

# %%
html.find("<table")

# %%
start_index = html.find("<table")
html[start_index:start_index+500]

# %%
soup = gazpacho.Soup(html)
type(soup)
# Out:
# gazpacho.soup.Soup
