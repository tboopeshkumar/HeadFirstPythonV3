# %%
import random

suits =["Clubs", "Spades", "Hearts", "Diamonds"]
faces = ["Jack", "Queen", "King", "Ace"]
numbered = [2,3,4,5,6,7,8,9,10]

# %%
suits
# Out:
# ['Clubs', 'Spades', 'Hearts', 'Diamonds']

# %%
def draw():
    the_suit = random.choice(suits)
    the_card = random.choice(faces+numbered)
    return the_card, "of", the_suit

# %%
print(draw())
# Out:
# ('Queen', 'of', 'Clubs')

# %%
for _ in range(5):
    print(draw())
# Out:
# ('Jack', 'of', 'Clubs')
# ('King', 'of', 'Diamonds')
# (9, 'of', 'Spades')
# (10, 'of', 'Clubs')
# ('Jack', 'of', 'Diamonds')

# %%
deck = set()

# %%
type(deck)
# Out:
# set

# %%
len(deck)
# Out:
# 0

# %%
print(dir(deck))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
help(deck.add)
# Out:
# Help on built-in function add:
#
# add(...) method of builtins.set instance
#     Add an element to a set.
#
#     This has no effect if the element is already present.

# %%
for suit in suits:
    for card in faces + numbered:
        deck.add((card, "of", suit))

# %%
len(deck)
# Out:
# 52

# %%
print(deck)
# Out:
# {(9, 'of', 'Clubs'), (2, 'of', 'Hearts'), (10, 'of', 'Clubs'), (6, 'of', 'Diamonds'), (2, 'of', 'Spades'), (7, 'of', 'Diamonds'), ('Ace', 'of', 'Hearts'), ('Ace', 'of', 'Spades'), (8, 'of', 'Hearts'), ('Queen', 'of', 'Diamonds'), (6, 'of', 'Clubs'), (4, 'of', 'Diamonds'), (7, 'of', 'Clubs'), (8, 'of', 'Spades'), (3, 'of', 'Diamonds'), (5, 'of', 'Diamonds'), (9, 'of', 'Hearts'), (9, 'of', 'Spades'), ('Queen', 'of', 'Clubs'), (10, 'of', 'Hearts'), ('King', 'of', 'Diamonds'), ('Jack', 'of', 'Diamonds'), (4, 'of', 'Clubs'), (10, 'of', 'Spades'), (5, 'of', 'Clubs'), (3, 'of', 'Clubs'), (6, 'of', 'Hearts'), ('King', 'of', 'Clubs'), (2, 'of', 'Diamonds'), ('Jack', 'of', 'Clubs'), (6, 'of', 'Spades'), (7, 'of', 'Hearts'), (7, 'of', 'Spades'), ('Ace', 'of', 'Diamonds'), ('Queen', 'of', 'Hearts'), (4, 'of', 'Hearts'), (8, 'of', 'Diamonds'), (2, 'of', 'Clubs'), ('Queen', 'of', 'Spades'), (4, 'of', 'Spades'), (3, 'of', 'Hearts'), (5, 'of', 'Hearts'), (5, 'of', 'Spades'), (9, 'of', 'Diamonds'), ('Ace', 'of', 'Clubs'), ('King', 'of', 'Hearts'), (3, 'of', 'Spades'), ('Jack', 'of', 'Hearts'), (10, 'of', 'Diamonds'), (8, 'of', 'Clubs'), ('King', 'of', 'Spades'), ('Jack', 'of', 'Spades')}

# %%
card = random.choice(list(deck))
print(card)
# Out:
# ('Ace', 'of', 'Spades')

# %%
def draw():
    card = random.choice(list(deck))
    deck.remove(card)
    return card

# %%
draw()
# Out:
# ('Queen', 'of', 'Spades')

# %%
len(deck)
# Out:
# 51

# %%
card in deck
# Out:
# True

# %%
import this

# %%
import antigravity

# %%
i = 0
while i < 10:
    print(i)
    i = i +1
